# %%
#Import libraries
import pandas as pd

# %%
#Useful Methods

# %%
#Create a DataFrame
df_mental_illness = pd.read_csv('rawdata//mental-illnesses-prevalence.csv')
df_mental_illness
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6415     Zimbabwe  ZWE  2015
# 6416     Zimbabwe  ZWE  2016
# 6417     Zimbabwe  ZWE  2017
# 6418     Zimbabwe  ZWE  2018
# 6419     Zimbabwe  ZWE  2019
#
#       Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.223206
# 1                                              0.222454
# 2                                              0.221751
# 3                                              0.220987
# 4                                              0.220183
# ...                                                 ...
# 6415                                           0.201042
# 6416                                           0.201319
# 6417                                           0.201639
# 6418                                           0.201976
# 6419                                           0.202482
#
#       Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              4.996118
# 1                                              4.989290
# 2                                              4.981346
# 3                                              4.976958
# 4                                              4.977782
# ...                                                 ...
# 6415                                           3.407624
# 6416                                           3.410755
# 6417                                           3.411965
# 6418                                           3.406929
# 6419                                           3.395476
#
#       Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              4.713314
# 1                                              4.702100
# 2                                              4.683743
# 3                                              4.673549
# 4                                              4.670810
# ...                                                 ...
# 6415                                           3.184012
# 6416                                           3.187148
# 6417                                           3.188418
# 6418                                           3.172111
# 6419                                           3.137017
#
#       Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                              0.703023
# 1                                              0.702069
# 2                                              0.700792
# 3                                              0.700087
# 4                                              0.699898
# ...                                                 ...
# 6415                                           0.538596
# 6416                                           0.538593
# 6417                                           0.538589
# 6418                                           0.538585
# 6419                                           0.538580
#
#       Eating disorders (share of population) - Sex: Both - Age: Age-standardized
# 0                                              0.127700
# 1                                              0.123256
# 2                                              0.118844
# 3                                              0.115089
# 4                                              0.111815
# ...                                                 ...
# 6415                                           0.095652
# 6416                                           0.096662
# 6417                                           0.097330
# 6418                                           0.097909
# 6419                                           0.098295
#
# [6420 rows x 8 columns]

# %%
df_mental_illness.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.223206
# 1                                           0.222454
# 2                                           0.221751
# 3                                           0.220987
# 4                                           0.220183
#
#    Depressive disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.996118
# 1                                           4.989290
# 2                                           4.981346
# 3                                           4.976958
# 4                                           4.977782
#
#    Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           4.713314
# 1                                           4.702100
# 2                                           4.683743
# 3                                           4.673549
# 4                                           4.670810
#
#    Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized  \
# 0                                           0.703023
# 1                                           0.702069
# 2                                           0.700792
# 3                                           0.700087
# 4                                           0.699898
#
#    Eating disorders (share of population) - Sex: Both - Age: Age-standardized
# 0                                           0.127700
# 1                                           0.123256
# 2                                           0.118844
# 3                                           0.115089
# 4                                           0.111815

# %%
column_names = df_mental_illness.columns
print(column_names)
for column in column_names:
    print(column)
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized',
#        'Eating disorders (share of population) - Sex: Both - Age: Age-standardized'],
#       dtype='object')
# Entity
# Code
# Year
# Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized
# Depressive disorders (share of population) - Sex: Both - Age: Age-standardized
# Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized
# Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized
# Eating disorders (share of population) - Sex: Both - Age: Age-standardized

# %%
#column_rename = {Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized}
df_mental_illness.rename(columns={"Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized" : "Schizophrenia"}, inplace=True)

# %%
new_column_names = {"Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized" : "Schizophrenia",'Depressive disorders (share of population) - Sex: Both - Age: Age-standardized':'Depression','Anxiety disorders (share of population) - Sex: Both - Age: Age-standardized':'Anxiety','Bipolar disorders (share of population) - Sex: Both - Age: Age-standardized':'Bipolar','Eating disorders (share of population) - Sex: Both - Age: Age-standardized':'Eating Disorder'}

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/CodeYouOrg/DataOpenClass/refs/heads/main/SalaryData.csv'
df = pd.read_csv(url)

# dropping columns we dont need
columns_to_drop = ['Overtime_Rate',	'Incentive_Allowance', 'Other', 'ObjectId']
df = df.drop(columns=columns_to_drop)

# We dont have a ton of missing data so we are dropping the NaNs 
df = df.dropna()

df = df[(df['CalYear'] == 2022) & (df['YTD_Total'] >= 100000)]

top_10_earners = df.groupby('Employee_Name')['YTD_Total'].sum().sort_values(ascending=False).head(10)
top_10_earners.plot(
    kind='bar',
    xlabel = 'Employee_Name',
    ylabel = 'YTD_Total',
    title='Top 10 Salaries in 2022',
    fontsize='18'
    )

print(top_10_earners.plot)
# Out:
# <pandas.plotting._core.PlotAccessor object at 0x0000020F7674B240>
